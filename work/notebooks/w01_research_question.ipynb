# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mohamed-6513/flyrank_ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Lane 1: Content Action Playbook (Content Decay & Refresh).
# I chose this lane because predicting traffic decay before it becomes irreversible saves valuable editorial hours and directly impacts revenue retention, making it a highly actionable business problem.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No code needed for this section.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# For content editors and SEO managers, deciding which decaying pages to prioritize for a content refresh each month, we will build a ranked scoring model from historical Search Console performance trends. A wrong call costs wasted editing hours on healthy pages (False Positives) or uncaptured traffic loss to competitors (False Negatives).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No code needed for this section.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains historical performance metrics. Let's load the raw data to see the volume of pages we are working with and the baseline traffic metrics, which confirms there is enough data density to train a ranking model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd


url = 'https://raw.githubusercontent.com/mohamed-6513/flyrank_ml/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)


print(f"Total rows in dataset: {len(df)}")
print(f"Number of columns: {len(df.columns)}")
print(f"Sample columns: {list(df.columns)[:4]}")
# Out:
# Total rows in dataset: 30000
# Number of columns: 44
# Sample columns: ['content_id', 'client_id', 'search_volume', 'competition']

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# We will claim only decision-support ranking recommendations based on observed directional trends. We will not claim causal proof of traffic recovery, and we will never claim to reverse-engineer or "predict Google" algorithms.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No code needed for this section.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
